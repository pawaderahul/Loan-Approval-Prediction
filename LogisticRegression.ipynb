# %%
# %run DataPreprocessing.ipynb

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf_lr= LogisticRegression()

# %%
clf_lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred= clf_lr.predict(X_train)

# %%
y_test_pred= clf_lr.predict(X_test)

# %% [markdown]
# ## Evaluating Performance

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_train,y_train_pred)
# Out:
# array([[ 82, 110],
#        [  7, 415]], dtype=int64)

# %%
metrics.accuracy_score(y_train,y_train_pred)
# Out:
# 0.8094462540716613

# %%
test['Loan_Status']= y_test_pred

# %%
sol_lr = test.drop(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Total_income', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area_Semiurban','Property_Area_Urban'], axis=1)

# %%
sol_lr['Loan_Status']=sol_lr['Loan_Status'].map({1:'Y',0:'N'})

# %%
sol_lr.head()
# Out:
#     Loan_ID Loan_Status
# 0  LP001015           Y
# 1  LP001022           Y
# 2  LP001031           Y
# 3  LP001035           Y
# 4  LP001051           Y
